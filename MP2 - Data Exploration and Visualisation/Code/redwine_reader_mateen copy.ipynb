# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics
from scipy.spatial.distance import cdist
from sklearn import preprocessing as prep

# %%
red = pd.read_excel('../Data/winequality-red.xlsx', skiprows=1)
white = pd.read_excel('../Data/winequality-white.xlsx', skiprows=1)

# %%
red.shape
# Out:
# (1599, 12)

# %%
red.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 123             8.0             0.710         0.00             2.6      0.080
# 1577            6.2             0.700         0.15             5.1      0.076
# 484            10.6             0.440         0.68             4.1      0.114
# 1165            8.5             0.440         0.50             1.9      0.369
# 104             7.2             0.490         0.24             2.2      0.070
# 96              6.8             0.775         0.00             3.0      0.102
# 1133            7.2             0.480         0.07             5.5      0.089
# 1261            6.3             1.020         0.00             2.0      0.083
# 639             8.9             0.290         0.35             1.9      0.067
# 1498            6.6             0.895         0.04             2.3      0.068
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 123                  11.0                  34.0  0.99760  3.44       0.53
# 1577                 13.0                  27.0  0.99622  3.54       0.60
# 484                   6.0                  24.0  0.99700  3.06       0.66
# 1165                 15.0                  38.0  0.99634  3.01       1.10
# 104                   5.0                  36.0  0.99600  3.33       0.48
# 96                    8.0                  23.0  0.99650  3.45       0.56
# 1133                 10.0                  18.0  0.99684  3.37       0.68
# 1261                 17.0                  24.0  0.99437  3.59       0.55
# 639                  25.0                  57.0  0.99700  3.18       1.36
# 1498                  7.0                  13.0  0.99582  3.53       0.58
#
#       alcohol  quality
# 123       9.5        5
# 1577     11.9        6
# 484      13.4        6
# 1165      9.4        5
# 104       9.4        5
# 96       10.7        5
# 1133     11.2        7
# 1261     11.2        4
# 639      10.3        6
# 1498     10.8        6

# %%
red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
#check for missing values
red.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#check for duplicates
red.duplicated().sum()
# Out:
# np.int64(240)

# %%
red_clean = red.drop_duplicates()
red_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
red_clean.shape
# Out:
# (1359, 13)

# %%
red.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
red.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
white.shape
# Out:
# (4898, 12)

# %%
white.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 689             6.7             0.170         0.37            2.00      0.039
# 3663            6.5             0.260         0.31            1.30      0.034
# 2010            7.0             0.250         0.56            2.00      0.035
# 2753            5.8             0.315         0.27            1.55      0.026
# 3533            6.6             0.220         0.30           14.70      0.045
# 95              7.1             0.260         0.29           12.40      0.044
# 4620            6.4             0.380         0.19            4.50      0.038
# 1742            6.3             0.250         0.23           14.90      0.039
# 542             5.5             0.350         0.35            1.10      0.045
# 833             6.9             0.250         0.34            1.30      0.035
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 689                  34.0                 125.0  0.99220  3.26       0.60
# 3663                 59.0                 145.0  0.98944  3.16       0.54
# 2010                 20.0                  95.0  0.99180  3.23       0.53
# 2753                 15.0                  70.0  0.98994  3.37       0.40
# 3533                 50.0                 136.0  0.99704  3.14       0.37
# 95                   62.0                 240.0  0.99690  3.04       0.42
# 4620                 36.0                 119.0  0.99151  3.07       0.42
# 1742                 47.0                 142.0  0.99705  3.14       0.35
# 542                  14.0                 167.0  0.99200  3.34       0.68
# 833                  27.0                  82.0  0.99045  3.18       0.44
#
#       alcohol  quality
# 689      10.8        7
# 3663     12.4        6
# 2010     11.0        6
# 2753     11.9        8
# 3533     10.6        6
# 95        9.2        6
# 4620     11.2        6
# 1742      9.7        6
# 542       9.9        6
# 833      12.2        6

# %%
white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
white.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
white.duplicated().sum()
# Out:
# np.int64(937)

# %%
white.drop_duplicates()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 6                    30.0                 136.0  0.99490  3.18       0.47
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 6         9.6        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [3961 rows x 12 columns]

# %%
white.shape
# Out:
# (4898, 12)

# %%
white.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
white.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
red["type"] = "red"
white["type"] = "white"

wine_df = pd.concat([red, white], ignore_index=True)

# %%
wine_df.shape
# Out:
# (6497, 13)
